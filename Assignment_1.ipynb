# %% [markdown]
# <h1 align='center'> COMP2420/COMP6420 - Introduction to Data Management,<br/> Analysis and Security</h1>
#
# <h1 align='center'> Assignment - 1</h1>
#
# -----
# <br/>
#
# ## Grading
#
# |**Maximum Marks**         |**100**
# |--------------------------|--------
# |  **Weight**              |  **15% of the Total Course Grade**
# |  **Submission deadline** |  **11:59PM, Friday, March 31**
# |  **Submission mode**     |  **Electronic, Using GitLab**
# |  **Penalty**             |  **100% after the deadline**
#
#
# ## Learning Outcomes
# The following learning outcomes apply to this piece:
# - **LO3** - Demonstrate basic knowledge and understanding of descriptive and predictive data analysis methods, optimization and search, and knowledge representation.
# - **LO4** - Formulate and extract descriptive and predictive statistics from data
# - **LO5** - Analyse and interpret results from descriptive and predictive data analysis
# - **LO6** - Apply their knowledge to a given problem domain and articulate potential data analysis problems
#
#
# ## Submission
#
# You need to submit the following items:
# - The notebook `Assignment_1_2023_uXXXXXXX.ipynb` (where uXXXXXXX is your uid)
# - A completed `statement-of-originality.md`, found in the root of the forked gitlab repo.
#
# Submissions are performed by pushing to your forked GitLab assignment repository. For a refresher on forking and cloning repositories, please refer to `Lab 1`. Issues with your Git repo (with the exception of a CECS/ANU wide Gitlab failure) will not be considered as grounds for an extension. You will also need to add your details below. Any variation of this will result in a `zero mark`.
#
# *****
#
# ### Notes:
#
# * It is strongly advised to read the whole assignment before attempting it and have at least a cursory glance at the dataset in order to gauge the requirements and understand what you need to do as a bigger picture.
# * Backup your assignment to your Gitlab repo often.
# * Extra reading and research will be required. Make sure you include all references in your Statement of Originality. If this does not occur, at best marks will be deduced. Otherwise, academic misconduct processes will be followed.
# * For answers requiring free form written text, use the designated cells denoted by `YOUR WRITTEN ANSWER HERE` -- double click on the cell to write inside them. Leave it blank if you don't have anything to write.
# * For all coding questions please write your code after the comment `YOUR CODE HERE`. Remember to document your code using comments and doc strings as appropriate.
# * In the process of testing your code, you can insert more cells or use print statements for debugging, but when submitting your file remember to remove these cells and calls respectively. You are welcome to add additional cells to the final submission, provided they add value to the overall piece.
# * You will be marked on **correctness** and **readability** of your code, if your marker can't understand your code your marks may be deducted.
# * Comment your code.
# * Before submitting, restart the kernel in Jupyter Lab and re-run all cells before submitting your code. This will ensure the namespace has not kept any old variables, as these won't come across in submission and your code will not run. Without this, you could lose a significant number of marks.
#
# *****

# %% [markdown]
# ### Enter your Student ID below:

# %% [raw]
# Student ID here:u7156540

# %% [markdown]
# ## Introduction
#
# The study of sea ice in polar regions is of great importance due to the critical role that sea ice plays in global climate and ecosystem health. Sea ice covers vast expanses of the Arctic and Antarctic oceans, acting as a reflective surface that helps regulate the Earth's temperature by reflecting sunlight back into space. As such, changes in sea ice cover (herein, we refer it to as sea ice extent) can have significant impacts on global climate patterns and ocean currents. Sea ice also provides a critical habitat for a wide range of Arctic and Antarctic marine species, including krill, polar bears, and various species of seals. The health and abundance of these species are directly linked to the extent and duration of sea ice cover extent. Furthermore, sea ice serves as a major transportation route for commercial shipping and resource extraction. Given these factors, the study of sea ice in polar regions is essential for understanding and mitigating the impacts of climate change and ensuring the long-term sustainability of polar ecosystems and human societies.
#
# The primary focus of this assignment is to conduct a some basic data analysis of sea ice extent in the polar region. The analysis will be centered on the study of a given data set (SeaIceExtent.csv). Through this study, the goal is to gain a preliminary comprehension of how sea ice extent is changing in the polar regions over time. The analysis will involve the use of statistical tools and techniques to identify trends, patterns, and anomalies in the data, as well as to develop models, particularly, linear regression models, that can help predict future changes in sea ice cover. The findings of this study will be potentially valuable in informing policy decisions related to climate change mitigation and adaptation, as well as in guiding the development of sustainable strategies for managing polar resources and ecosystems. Overall, this assignment represents an important effort to contribute to our understanding of one of the most critical and rapidly changing aspects of the Earth's climate system. With all this in mind, I hope you find joy in engaging with this assignment beyond simply completing it.

# %% [markdown]
# *******************
# ## Package Imports

# %%
# Common Imports
import numpy as np
import pandas as pd
from scipy import stats
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
plt.style.use('seaborn')
# %matplotlib inline

# %%
import pandas as pd
import random

# 设置随机种子以获得可复现的结果
random.seed(0)

# 创建一个包含100个随机的 'a', 'b', 'c' 的列表
letters = [random.choice(['a', 'b', 'c']) for _ in range(100)]

# 创建一个包含100个随机数（范围在5-10之间）的列表
numbers = [random.randint(5, 10) for _ in range(100)]

# 创建一个数据框
df = pd.DataFrame({
    'Letters': letters,
    'Numbers': numbers
})




df.to_excel('random_data.xlsx', index=False, engine='openpyxl')

# %%
# Import additional modules here as required
#
# Note that only modules in the standard Anaconda distribution are allowed. 
# If you need to install it manually, it is not an accepted package.
#

# %%
df = pd.read_excel('a.xlsx')

df['a'] = df['Letters'].where(df['Letters']=='a','notA')

grouped = df.groupby('a')['Numbers'].apply(list).to_dict()

fig = plt.figure(figsize=(22,14))

plt.scatter(grouped['a'], grouped['a'])
#plt.xticks([1,2],["a", "Not A"])
plt.title("Boxplot of a and not_a")
plt.ylabel("Number of day stay at hospital")
plt.xlabel("If they use something")
plt.show()

from scipy.stats import ttest_1samp

from scipy.stats import pearsonr

corr, p_value = pearsonr(df["Numbers"],df["Numbers"])

t,p = stats.ttest_1samp(SeaIce["Sum_Arctic"], 10)
print("The result of one sample test's t_value is",t)
print("The result of one sample test's p_value is",p)

t1,p1 = stats.ttest_ind(SeaIce["Sum_Antarctic"],SeaIce["Sum_Arctic"])

print("The result of two sample test's is", t1)
print("The result of two sample test's p value is", p1)

print(corr)
# Out:
# The result of one sample test's t_value is 45.699835288589824
# The result of one sample test's p_value is 0.0
# The result of two sample test's is 6.612327265346739
# The result of two sample test's p value is 3.848683949384268e-11
# 0.9999999999999998

# %% [markdown]
# **Several notes on printing and plotting**
# * Throughout this assignment, when writing codes to print, your codes should <u>**include the relevant units and/or give relevant description**</u> of what you are printing.
#
# * A professional plot typically has the following characteristics:
#
#     * Clear and concise labeling: A professional plot should have clear and concise labeling of the x and y axes, as well as a clear title that conveys the purpose of the plot.
#
#     * Appropriate scales: The scales on the x and y axes should be appropriate for the data being presented. This means that the scales should be chosen so that the data is not too compressed or stretched out, and so that important features of the data are easily visible.
#
#     * Appropriate plot type: The plot type should be appropriate for the data being presented. For example, if the data is continuous, a line plot or a scatter plot may be appropriate. If the data is categorical, a bar chart or a pie chart may be more appropriate.
#
#     * Clarity: A professional plot should be visually clear and easy to interpret. This means that unnecessary elements should be removed, colors should be used judiciously, and the plot should be free of clutter.
#
#     * Consistency: A professional plot should be consistent in its formatting with other plots that may be presented in the same report. This means that font sizes, line widths, and colors should be consistent across all plots.

# %% [markdown]
# ****
# ## Q1: Loading and Basic Analysis of the Data
#
# Briefly state your work on each Task and justify your decisions. For example, when using an existing function, briefly state what the function does (e.g., a mean function calculates the average values of the ensambles).
#
#
# #### Task 1: Load the data file SeaIceExtent.csv into a Pandas DataFrame and make it ready for use. (4 marks)
#
# **Hints:**
# * You might want to drop unnecessary or rededundant columns and/or rows.
#
# * You might want to rename some columns and/or rows.

# %%
# YOUR CODE HERE

# (ADD ANY ADDITIONAL CELLS AS REQUIRED; Same below)
SeaIce = pd.read_csv("SeaIceExtent.csv") # read date from csv and make it in dataframe
SeaIce = SeaIce.dropna(axis=1) # remove the empty column
SeaIce = SeaIce.drop(0) #remove the first row as it is unit
SeaIce.columns = [col.replace(' ','') for col in SeaIce.columns] #remove the empty space.

# covert the column 'Year','Month','Day',"Extent(Antarctic)","Extent(Arctic)","Missing(Antarctic)","Missing(Arctic)" from string to numerical 
SeaIce['Year'] = SeaIce['Year'].astype(int)
SeaIce['Month'] = SeaIce['Month'].astype(int)
SeaIce['Day'] = SeaIce['Day'].astype(int)
SeaIce["Extent(Antarctic)"] = SeaIce["Extent(Antarctic)"].astype(float)
SeaIce["Extent(Arctic)"] = SeaIce["Extent(Arctic)"].astype(float)
SeaIce["Missing(Antarctic)"] = SeaIce["Missing(Antarctic)"].astype(float)
SeaIce["Missing(Arctic)"] = SeaIce["Missing(Arctic)"].astype(float)

# %% [raw]
# # YOUR WRITTEN ANSWER HERE
# # There is an empty column between Missing(Arctic) and SourceData and it is unnecessary, so drop it.

# %% [markdown]
# #### Task 2: Data basic visualisation
#
# - Task 2.1: Access the data and print the Antarctic and Arctic sea ice extents of week 2 of S1 2023 (February 27 to March 3, 2023). (2 marks)

# %%
# YOUR CODE HERE

#start of week2
start='2023-02-27'

#end of week2
end='2023-03-03'

#create a new column in dataframe to record the date of each row
SeaIce["Date"] = pd.to_datetime(SeaIce[["Year","Month","Day"]])

# check whether the row is within week2 for all sea ice extent
is_date = (SeaIce['Date'] >= start) & (SeaIce["Date"] <= end)

# get the data in week 2 of s1 2023
week_two = SeaIce.loc[is_date]


#print(week_two[['Date','Extent(Antarctic)','Extent(Arctic)']])
for i in range(0,len(week_two)):
    print("The date: ",week_two.iloc[i]["Date"],"has Antarctic sea ice extents ",week_two.iloc[i]["Extent(Antarctic)"],
          "10^6 km sq and Arctic sea ice extents ",week_two.iloc[i]["Extent(Arctic)"]," 10^6 km sq")
# Out:
# The date:  2023-02-27 00:00:00 has Antarctic sea ice extents  1.856 10^6 km sq and Arctic sea ice extents  14.462  10^6 km sq
# The date:  2023-02-28 00:00:00 has Antarctic sea ice extents  1.848 10^6 km sq and Arctic sea ice extents  14.476  10^6 km sq
# The date:  2023-03-01 00:00:00 has Antarctic sea ice extents  1.907 10^6 km sq and Arctic sea ice extents  14.529  10^6 km sq
# The date:  2023-03-02 00:00:00 has Antarctic sea ice extents  1.908 10^6 km sq and Arctic sea ice extents  14.627  10^6 km sq
# The date:  2023-03-03 00:00:00 has Antarctic sea ice extents  1.877 10^6 km sq and Arctic sea ice extents  14.61  10^6 km sq

# %% [raw]
# # YOUR WRITTEN ANSWER HERE
# # In order to filter the date, first convert year,month,day to date.

# %% [markdown]
# - Task 2.2: In one figure, plot the daily trend of the Antarctic and Arctic sea ice extents.  (4 marks)

# %%
# YOUR CODE HERE

fig = plt.figure(figsize=(22,14))


x = SeaIce["Date"]
y = SeaIce["Extent(Antarctic)"]
z = SeaIce["Extent(Arctic)"]

plt.plot(x,y,label="Antarctic")
plt.plot(x,z,label="Arctic")

plt.xlabel("Date")
plt.ylabel("Sea Ice extents(10^6 sq km)")
plt.title("Daily trend of the Antarctic and Arctic sea ice extents")

plt.legend()
plt.show()

# %% [raw]
# # YOUR WRITTEN ANSWER HERE

# %% [markdown]
# #### Task 3: Data basic processing
#
# - Task 3.1: Identify the missing dates (the dates when the sea ice extents are not available): Store the total number of dates of each year in a table where each row specifies the year (column 1) and the total number of dates (column 2). Print the table. (4 marks)

# %%
# YOUR CODE HERE

#Select the data range by date in dataframe
date_range = pd.date_range(start=SeaIce["Date"].iloc[0], end=SeaIce["Date"].iloc[-1])

#Use the not in method find out the missing sea ice
missing = date_range[~date_range.isin(SeaIce['Date'])]

#Get the year of missing date and make them in a dataframe
dfMissing = pd.DataFrame({"Year":missing.year})

#use the groupby method to count the number of missing days for each year
counts = dfMissing.groupby("Year").size()

print(counts)
# Out:
# Year
# 1978     33
# 1979    183
# 1980    183
# 1981    182
# 1982    183
# 1983    182
# 1984    183
# 1985    183
# 1986    182
# 1987    145
# 1988     12
# dtype: int64

# %% [raw]
# # YOUR WRITTEN ANSWER HERE

# %% [markdown]
# - Task 3.2: Evaluate the sea ice extent monthly averages; then similar to Task 2.2, in one figure, plot the monthly trend of the Antarctic and Arctic sea ice extents. (4 marks)

# %%
# YOUR CODE HERE


# Use groupby method to select the same year and month,then calculate mean of them
mean_extent = SeaIce.groupby(['Year','Month'])[["Extent(Antarctic)","Extent(Arctic)"]].mean()

# print out the table of sea ice extent monthly averages
print(mean_extent[['Extent(Antarctic)',"Extent(Arctic)"]])

# Plot the graph
mean_extent.plot(figsize=(22,16),xlabel='Month',ylabel='Average of Sea Ice extents(10^6 sq km)',title="Monthly trend of the Antarctic and Arctic sea ice extents")
# Out:
#             Extent(Antarctic)  Extent(Arctic)
# Year Month
# 1978 10             17.699000       10.402667
#      11             15.896400       11.645133
#      12             10.395250       13.667063
# 1979 1               5.402200       15.414000
#      2               3.141071       16.175286
# ...                       ...             ...
# 2022 11             15.062033        9.712067
#      12              8.690161       11.917290
# 2023 1               3.230065       13.346290
#      2               1.912607       14.176179
#      3               1.926833       14.605333
#
# [534 rows x 2 columns]
# <AxesSubplot:title={'center':'Monthly trend of the Antarctic and Arctic sea ice extents'}, xlabel='Month', ylabel='Average of Sea Ice extents(10^6 sq km)'>

# %% [raw]
# # YOUR WRITTEN ANSWER HERE

# %% [markdown]
# #### Task 4: Study the central tendency of the data
#
# Recall from Lecture 3 that the most common measures of centre tendency are the 3M: Mode, Median, and
# Mean. We study these 3Ms one-by-one as below.
#
# - Task 4.1: Calculate and print the mode of both the Antarctic and Arctic sea ice extents. For this calculation, round both the Antarctic and Arctic sea ice extents to the nearest million. (4 marks)

# %%
# YOUR CODE HERE
import math

#mode of Antarctic ice extent
mode_Antarctic = SeaIce["Extent(Antarctic)"].mode()

#mode of Arctic ice extent
mode_Arctic = SeaIce["Extent(Arctic)"].mode()

#print each mode in a list of mode
for i in range(0,len(mode_Antarctic)):
    print("The",i+1,"th of mode in Antarctic is",round(mode_Antarctic[i]))

for i in range(0,len(mode_Arctic)):
    print("The",i+1,"th of mode in Arctic is",round(mode_Arctic[i]))
# Out:
# The 1 th of mode in Antarctic is 17
# The 2 th of mode in Antarctic is 18
# The 1 th of mode in Arctic is 14

# %% [raw]
# # YOUR WRITTEN ANSWER HERE

# %% [markdown]
# - Task 4.2: Calculate and print the median of both the Antarctic and Arctic sea ice extents (2 marks)

# %%
# YOUR CODE HERE

#median of both the antarctic and arctic ice extents
median_Antarctic = np.median(SeaIce["Extent(Antarctic)"])
median_Arctic = np.median(SeaIce["Extent(Arctic)"])

print("Median of Antarctic sea ice is" ,median_Antarctic)
print("Median of Arctic sea ice is",median_Arctic)
# Out:
# Median of Antarctic sea ice is 12.543
# Median of Arctic sea ice is 11.981

# %% [raw]
# # YOUR WRITTEN ANSWER HERE

# %% [markdown]
# - Task 4.3: Calculate and print the mean of both the Antarctic and Arctic sea ice extents (2 marks)

# %%
# YOUR CODE HERE

# mean of each seaice extent
mean_Antarctic = np.mean(SeaIce["Extent(Antarctic)"])
mean_Arctic = np.mean(SeaIce["Extent(Arctic)"])
print("Mean of Antarctic sea ice is ",round(mean_Antarctic,4))
print("Mean of Arctic sea ice is ",round(mean_Arctic,4))
# Out:
# Mean of Antarctic sea ice is  11.6129
# Mean of Arctic sea ice is  11.2535

# %% [raw]
# # YOUR WRITTEN ANSWER HERE

# %% [markdown]
# #### Task 5: Study the variability of the data
#
# - Task 5.1: Create two new columns to store the sums of the missing extents and the corresponding polar regions (adding Missing Antarctic to Antarctic; adding Missing Arctic to Arctic). (2 marks)

# %%
# YOUR CODE HERE

SeaIce["Sum_Antarctic"] = SeaIce["Extent(Antarctic)"]+SeaIce["Missing(Antarctic)"] #Add up the missing antarctic sea ice to antarctic
SeaIce["Sum_Arctic"] = SeaIce["Extent(Arctic)"]+SeaIce["Missing(Arctic)"]#Add up the missing arctic sea ice to arctic

# %% [raw]
# # YOUR WRITTEN ANSWER HERE

# %% [markdown]
# - Task 5.2: Using the two new columns, calculate and print the range of both the Antarctic and Arctic sea ice extents (2 marks)

# %%
# YOUR CODE HERE 

# Use method min and max to find out the range
print("The range of Antarctic sea ice extent is between" ,SeaIce["Sum_Antarctic"].min(),"to",SeaIce["Sum_Antarctic"].max())
print("The range of Arctic sea ice extent is" ,SeaIce["Sum_Arctic"].min(),"to",SeaIce["Sum_Arctic"].max())
# Out:
# The range of Antarctic sea ice extent is between 1.766 to 20.201
# The range of Arctic sea ice extent is 3.34 to 16.635

# %% [raw]
# # YOUR WRITTEN ANSWER HERE

# %% [markdown]
# - Task 5.3: Using the two new columns, calculate and print the variance of both the Antarctic and Arctic sea ice extents (2 marks)

# %%
# YOUR CODE HERE

# calculate the variance of sum of Antarctic and sum of Arctic
var_ant = SeaIce["Sum_Antarctic"].var()
var_arc = SeaIce["Sum_Arctic"].var()
print("The variacne of two Antarctic sea ice extent is",round(var_ant,4))
print("The variacne of two Arctic sea ice extent is",round(var_arc,4))
# Out:
# The variacne of two Antarctic sea ice extent is 32.0391
# The variacne of two Arctic sea ice extent is 10.9491

# %% [raw]
# # YOUR WRITTEN ANSWER HERE

# %% [markdown]
# - Task 5.4: Using the two new columns, calculate and print the standard deviation of both the Antarctic and Arctic sea ice extents (2 marks)

# %%
# YOUR CODE HERE

# calculate the standard diviation of sum of Antarctic and sum of Arctic

std_ant = SeaIce["Sum_Antarctic"].std()
std_arc = SeaIce["Sum_Arctic"].std()

print("The standard deviation of two Antarctic sea ice extent is",round(std_ant,4))
print("The standard deviation of two Arctic sea ice extent is",round(std_arc,4))
# Out:
# The standard deviation of two Antarctic sea ice extent is 5.6603
# The standard deviation of two Arctic sea ice extent is 3.3089

# %% [raw]
# # YOUR WRITTEN ANSWER HERE

# %% [markdown]
# ******
# ## Q2: EXPLORATORY DATA ANALYSIS
#
# In this section you are expected to do an exploratory data analysis on the dataset. Herein, we use the data generated in Task 5.1.
#
# - Task 1: Explore the correlation of the Antarctic and Arctic sea ice extents. You need to use both plot/plots and correlation test. (6 marks)

# %%
# YOUR CODE HERE
from scipy.stats import pearsonr

#set the size of plot
fig = plt.figure(figsize=(22,18)) 

#calculate the correaltion and p_value for the relationship
corr, p_value = pearsonr(SeaIce["Sum_Antarctic"],SeaIce["Sum_Arctic"])
print("The correlation of Antarctic and Arctic sea ice extents is ",corr)
print("The p_value is ",p_value)

#set x value and y value
x = SeaIce["Sum_Arctic"]
y = SeaIce["Sum_Antarctic"]

#draw the scatter plot for Arctic and Antarctic
plt.scatter(x,y,label='Sea Ice extent')


#set the title,label for x and y and legent
plt.xlabel("Arctic sea ice extent")
plt.ylabel("Antarctic sea ice extent")
plt.title("Correlation of the Antarctic and Arctic sea ice extents")
plt.legend()

plt.show()
# Out:
# The correlation of Antarctic and Arctic sea ice extents is  -0.91872200597183
# The p_value is  0.0

# %% [raw]
# # YOUR WRITTEN ANSWER HERE
# The scatter plot is tend to have a straight line shows there is a correlation between Arctic sea ice extent and Antarctic ice extent. From left to right, the data point move down, which means there is a negative correlation.
#
# The correlation coeficient is -0.91,which means there is a strong negative correaltion between the Antarctic and Arctic sea ice extents. The p value is 0.0,which less than the 0.0001,reject the null hypothesis:there is no correaltion between Arctic SeaIce extent and Antrctic SeaIce extent, shows there is a correlation between the Antarctic and Arctic sea ice extents.

# %% [markdown]
# - Task 2: Shift the Arctic sea ice extent **forward** by six months (for example, this shift moves the date 15/01/2000 to 15/07/2000) and process your data appriopriately so that the dates match (4 marks)
#
#     **Hints**: (a) basically you want to remove the first six months of the Antarctic sea ice extent and the last six months so that the time window matches; (b) there are dates where either Antarctic sea ice extent or Arctic sea ice extent is missing; remove these rows to match.

# %%
# YOUR CODE HERE
SeaIce.head()

#create a first dataframe,contain only date and Arctic seaice extent
df1 = pd.DataFrame({'date': SeaIce["Date"], 'arc':SeaIce["Sum_Arctic"] })

#shift the date forward six month base on the first dataframe
df1['date'] = df1['date'] + pd.DateOffset(months=6)

#create second dataframe which contains sea ice extent of Antarctic only
df2 = pd.DataFrame({'date': SeaIce["Date"], 'ant': SeaIce["Sum_Antarctic"]})

#merge two data frame togother base on the date
shift_six = pd.merge(df1, df2, on='date')

# %% [raw]
# # YOUR WRITTEN ANSWER HERE

# %% [markdown]
# - Task 3: Explore the correlation of the new data set. (4 marks)

# %%
# YOUR CODE HERE

#set the plot size
fig = plt.figure(figsize=(22,18)) 

#return the correlation and p_value
corr,p = pearsonr(shift_six['arc'],shift_six['ant'])
print("The correlation of arctic extent and antarctic extent after shifting six month is",corr)
print("The p_value of the arctic extent and antarctic extent after shifting six month is",p)

#set the x and y value of plot and draw a scatter plot for them,then set the element of the graph
x = shift_six["arc"]
y = shift_six["ant"]
plt.scatter(x,y,label='Sea Ice Extent')
plt.xlabel("Arctic SeaIce extent")
plt.ylabel("Antarctic SeaIce extent")
plt.title("Correlation of the Antarctic and Arctic sea ice extents after shift six months")
plt.legend()

plt.show()
# Out:
# The correlation of arctic extent and antarctic extent after shifting six month is 0.9406944771157761
# The p_value of the arctic extent and antarctic extent after shifting six month is 0.0

# %% [raw]
# # YOUR WRITTEN ANSWER HERE
# The scatter plot is tend to have a straight line shows there is a correlation between Arctic sea ice extent and Antarctic ice extent. From left to right, the data point move up, which means there is a positive correlation.
#
# The correlation coeficient is 0.94,which means there is a strong correaltion between the Antarctic and Arctic sea ice extents after shifting six month. The p value is 0.0,which less than the 0.0001,reject the null hypothesis:there is no correaltion between Arctic SeaIce extent and Antrctic SeaIce extent, shows there is a correlation between the Antarctic and Arctic sea ice extents.

# %% [markdown]
# - Task 4: Compare the results of Task 3 with Task 1 and discuss the comparison. (4 marks)

# %%
# YOUR CODE HERE

# %% [raw]
# # YOUR WRITTEN ANSWER HERE
# # The result of both correlation's absolute value are larger than 0.9 and scatter plot in both task show there is a strong correaltion between the Arctic SeaIce extent and Antarctic SeaIce extent before and after shifting the date six month forward. The both p value are both less than the 0.05, from pearson, which indicate that we reject the null hypothesis:there is no correaltion between Arctic SeaIce extent and Antrctic SeaIce extent. Shows that there is a correaltionship between them.
#
# # The result of task1's correlation is -0.92 while task3's correlation is 0.94 and the graph also shows there is a positive correlation in task1 while negative correlation in task2. The periodic's difference between antarctic and arctic is 6 month.

# %% [markdown]
# - Task 5: Further exploration (12 marks)
#
#     * Perform Boxplot analysis of both the the Antarctic and Arctic sea ice extents and describe the boxplots and discuss the comparison of the two. (6 marks)
#
#     * Perform both one-sample (for Antartic sea ice extent with known value 1.0x10^7 square kilometers) and two-sample T-tests. (6 marks) **Hints** (a) The Lecture note 3 may be helpful (for example see page 49 regarding the definition); (b) Announce some descriptive stats on your data and explain what they mean in the context of this dataset.

# %%
# YOUR CODE HERE



# plot a box plot
plt.boxplot([SeaIce['Sum_Arctic'], SeaIce['Sum_Antarctic']])
plt.xticks([1,2],["Arctic", "Antarctic"])
plt.title("Boxplot of Antarctic and Arctic sea ice extents")
plt.ylabel("Extent of sea ice")
plt.xlabel("The location of sea")
plt.show()

from scipy.stats import ttest_1samp


t,p = stats.ttest_1samp(SeaIce["Sum_Arctic"], 10)
print("The result of one sample test's t_value is",t)
print("The result of one sample test's p_value is",p)

t1,p1 = stats.ttest_ind(SeaIce["Sum_Antarctic"],SeaIce["Sum_Arctic"])

print("The result of two sample test's is", t1)
print("The result of two sample test's p value is", p1)
# Out:
# The result of one sample test's t_value is 45.699835288589824
# The result of one sample test's p_value is 0.0
# The result of two sample test's is 6.612327265346739
# The result of two sample test's p value is 3.848683949384268e-11

# %%
plt.boxplot([SeaIce['Sum_Arctic'], SeaIce['Sum_Antarctic']])
plt.xticks([1,2],["Arctic", "Antarctic"])
plt.title("Boxplot of Antarctic and Arctic sea ice extents")
plt.ylabel("Extent of sea ice")
plt.xlabel("The location of sea")
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(['Sum_Arctic'], ['Sum_Antarctic'])' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Input In [46], in <cell line: 3>()
#       1 x = 'Sum_Arctic'
#       2 y = 'Sum_Antarctic'
# ----> 3 SeaIce[[x],[y]].boxplot()
#
# ...

# %% [raw]
# # YOUR WRITTEN ANSWER HERE
# # Boxplot analysis
# The boxplot graph shows that, the box of Arctic is overlap with in the Antarctic and both box plot's mean line lies to each other's box,which means the median of Arctic sea ice extent and Antarctic extent are not sufficently differently. The Antarctcic sea ice extent has wider range than Arctic sea ice extent. The Antarctic sea ice extent also has a larger box compare to the Arctic,both of these shows that the Antarctic sea ice extent has more spread out.
#
# As the p value is 0 and less than 0.05,we reject the null hypothesis:the mean of ntartic sea ice extent is equal to 1.0x10^7.So the mean of antartic sea ice extent is not equal to 1.0x10^7 square kilometers. In the meantime, the t-value,which indicate the difference between the means of two sea ice extent is large.
#
# As the p value is 3.848683949384268e-11 and less than 0.05, we reject the null hypothesis,so the mean of antartic sea ice extent and the mean of arctic sea ice extentis are not equal

# %% [markdown]
# ******
# ## Q3: Linear Regression
#
# The exciting stage is here! Your task is to create several Regression Models in this section. The goal is to build useful models (keep in mind that "All models are wrong, but some are useful", a quote by George Box) for forecasting the evolution of the sea ice extent. For this purpose and for simplicity, we focus on Antarctic region (only use data from the year 1980 to 2022 for the Antarctic sea ice except for Task 5 below). Herein, we use the data generated in Task 5.1. Specifically, the tasks are below.
#
#
# - Task 1: Use the data from the year 1980 to 2021 and build a linear regression model for the Antarctic sea ice extent. Specifically,
#
#     - The input (x-axis) of the model should be time (the j-th day since the first day in 01/01/1980) and the output is the predicted Antarctic sea ice extent, y-axis, for a given time/date). (4 marks)
#
#     - Visualise the model: in a scatter plot of the data from 1980 to 2021, draw the linear regression modeled line. (4 marks)
#
#     - Apply the model to predict the sea ice extend for the year of 2022. (2 marks)
#
#     - Visualise and plot the comparision of the predicted values of 2022 with the actual values from the data. (4 marks)
#
#     - Calculate the root mean squared error and R-squared value of the predicted values of 2022. (2 marks)

# %%
# YOUR CODE HERE

#select the data from 1980 to 2021
start_1 = "1980-01-01"
end_1 = "2021-12-31"
select = SeaIce.loc[(SeaIce["Date"]>=start_1)&(SeaIce["Date"]<=end_1)]

#creata a new column in dataframe,return the days since 1980.01.01

from datetime import datetime
select["j-th-day"] = (select['Date']-datetime(1980, 1, 1)).dt.days

#The x-input of model is the day since 1980.01.01 and the y is Antarctic sea ice extent,then create a new model
x = np.array(select["j-th-day"]).reshape(-1,1)
y = select["Sum_Antarctic"]
lr = LinearRegression()
model = lr.fit(x,y)

# Plot the scatter of all day's Antarctic sea ice extent since 1980.01.01
fig = plt.figure(figsize=(22,30))
ax1 = fig.add_subplot(211)
ax1.scatter(x,y,label='Daily Sea Ice extent')
ax1.set_title("Scatter plot of Antarctic sea ice extent from 1980 to 2021")
ax1.set_xlabel("Days since 1980.01.01")
ax1.set_ylabel("Sea Ice extent of Antarctic")


# Plot the linear regression model for the Antarctic sea ice extent and day since 1980.01.01
intercept = model.intercept_
coef = model.coef_[0]
x_range = [x.min(), x.max()]                    
y_range = [intercept+coef*x_range[0], intercept+coef*x_range[1]]
ax1.plot(x_range, y_range, c="red",label='regression line')
ax1.legend()

# Use the linear regression model we create to predict the 2022 Antarctic sea ice extent
x_2022 = range(select["j-th-day"].iloc[-1]+1,select["j-th-day"].iloc[-1]+1+365)
predict_2022 = [model.predict(np.array(x).reshape(-1,1)) for x in x_2022]
predict_2022 = [array[0] for array in predict_2022]

#Scatter plot of Antarctic sea ice extent's predict and actual in 2022
actual_2022 = SeaIce.loc[(SeaIce["Date"]>="2022-01-01")&(SeaIce["Date"]<="2022-12-31")]["Sum_Antarctic"]
ax2 = fig.add_subplot(212)
ax2.scatter(x_2022,predict_2022,color="blue",label='predict')
ax2.scatter(x_2022,actual_2022,color="green",label='actual')
ax2.set_title("Scatter plot of Antarctic sea ice extent's predict and actual in 2022")
ax2.set_xlabel("Days since 1980.01.01")
ax2.set_ylabel("Sea Ice extent of Antarctic")
ax2.legend()


from sklearn.metrics import mean_squared_error, r2_score

RMSE = mean_squared_error(actual_2022, predict_2022)
print("The RMSE between actual 2022 and predcit 2022 is:", math.sqrt(RMSE))

# Calculate R-squared
slope, intercept, r_value, p_value, std_err = stats.linregress(actual_2022, predict_2022)

r = r2_score(actual_2022, predict_2022)
print("The actual 2022 and predict 2022 has R-squared:", r)
# Out:
# /var/folders/w3/1bhj1k9n00jbh6lvpf14z78r0000gn/T/ipykernel_2044/3164300488.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   select["j-th-day"] = (select['Date']-datetime(1980, 1, 1)).dt.days
# The RMSE between actual 2022 and predcit 2022 is: 5.883533838576889
# The actual 2022 and predict 2022 has R-squared: -0.048003475544996954

# %% [raw]
# # YOUR WRITTEN ANSWER HERE

# %% [markdown]
# - Task 2: Perform the same study as above but build four linear regression models for each year where one for each season in the year (In Australia: December to February is summer; March to May is autumn; June to August is winter; and September to November is spring. **There are only four seasons**). (8 marks: the marks in each of the five parts in Task 1 above are halved)
#
#     **Requirements and hints are**
#
#     - Your model shall consists of line segments. Specifically, there should be four lines in each year (build a linear regression model for each season). Thus, in total, there should be 42*4=168 line segments.
#
#     - For better visualisation of your model, you may plot each of these line segments with one color for one season.
#
#     - In order to make a prediction about the extent of sea ice in 2022, we must use 168 line segments from the years 1980 to 2021 to create four line segments for 2022. To achieve this, we must determine the slopes and y-intercepts of these four line segments for 2022 using linear regression analysis. For example, we can use the 42 slopes of the lines of Springs over 1980 to 2021 to create a linear regression model to predict the slope of the line for Spring 2022.

# %%
# YOUR CODE HERE

#Set the figure size
fig = plt.figure(figsize=(25,30))
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

#Define a function,base on the given month,convert to the season and create a new column in select dataframe shows season
def to_season(Month):
    if (Month==12) | (Month==1)| (Month==2):
        return "Summer"
    if (Month==3) | (Month==4)| (Month==5):
        return "Autumn"
    if (Month==6) | (Month==7)| (Month==8):
        return "Winter"
    else:
        return "Spring"
select["season"] = select["Month"].apply(to_season)

#Collect intercept and coef for each season in 1980 to 2021,use these datas later to create a model to predict intercept and coef in 2022
intercept_autumn = []
coef_autumn = []

intercept_spring = []
coef_spring = []

intercept_winter = []
coef_winter = []

intercept_summer = []
coef_summer = []

#For each year between 1980 and 2021,create a model for each season,and draw the model on the plot,record the gradient and intercept of each.
for i in range(1980,2022):
    #create the model for autumn
    data = select[(select['season']=='Autumn') & (select['Year']==i)]
    x = np.array(data["j-th-day"]).reshape(-1,1)
    y = data['Sum_Antarctic']
    lr = LinearRegression()
    model = lr.fit(x,y)
    intercept = model.intercept_
    coef = model.coef_[0]
    y_min = x.min()*coef+intercept
    y_max = x.max()*coef+intercept
    x1 = [x.min(),x.max()]
    y1 = [y_min,y_max]
    #For each model created,add it to the list of autumn intercept and coefficient
    intercept_autumn.append(intercept)
    coef_autumn.append(coef)
    ax1.plot(x1,y1,color='red')
    
    #create the model for winter
    data = select[(select['season']=='Winter') & (select['Year']==i)]
    x = np.array(data["j-th-day"]).reshape(-1,1)
    y = data['Sum_Antarctic']
    lr = LinearRegression()
    model = lr.fit(x,y)
    intercept = model.intercept_
    coef = model.coef_[0]
    y_min = x.min()*coef+intercept
    y_max = x.max()*coef+intercept
    x1 = [x.min(),x.max()]
    y1 = [y_min,y_max]
    #For each model winter,add it to the list of winter intercept and coefficient
    intercept_winter.append(intercept)
    coef_winter.append(coef)
    ax1.plot(x1,y1,color='blue')
    
    #Create the model for spring
    data = select[(select['season']=='Spring') & (select['Year']==i)]
    x = np.array(data["j-th-day"]).reshape(-1,1)
    y = data['Sum_Antarctic']
    lr = LinearRegression()
    model = lr.fit(x,y)
    intercept = model.intercept_
    coef = model.coef_[0]
    y_min = x.min()*coef+intercept
    y_max = x.max()*coef+intercept
    x1 = [x.min(),x.max()]
    y1 = [y_min,y_max]
    #For each model winter,add it to the list of spring intercept and coefficient
    intercept_spring.append(intercept)
    coef_spring.append(coef)
    ax1.plot(x1,y1,color='green')
    
    #Create the model for summer,for summer one,need to consider the previouse year's Decemeber and this year's Jan,Feb
    data = select[(select['season']=='Summer') & (((select['Year']==i) & ((select['Month']==1) | (select['Month']==2))) | ((select['Year']==(i-1)) & (select['Month']==12)))]
    x = np.array(data["j-th-day"]).reshape(-1,1)
    y = data['Sum_Antarctic']
    lr = LinearRegression()
    model = lr.fit(x,y)
    intercept = model.intercept_
    coef = model.coef_[0]
    y_min = x.min()*coef+intercept
    y_max = x.max()*coef+intercept
    x1 = [x.min(),x.max()]
    y1 = [y_min,y_max]
    #For each model summer,add it to the list of spring intercept and coefficient
    intercept_summer.append(intercept)
    coef_summer.append(coef)
    ax1.plot(x1,y1,color='black')

#Plot the graph of Linear regression model line for each season between 1980 and 2022
ax1.set_title('Linear regression model line for each season between 1980 and 2022')
ax1.set_xlabel('Days since 1980-01-01')
ax1.set_ylabel('Antarctic Sea Ice extent')
ax1.legend(['Autumn','Winter','Spring','Summer'])

#Calculte the model for Autumn 2022
ln = LinearRegression()

intercept_autumn = intercept_autumn[27:]
coef_autumn = coef_autumn[27:]

year_since_1980 = np.array(list(range(len(intercept_autumn)))).reshape(-1,1)
model_intercept = ln.fit(year_since_1980,intercept_autumn)
intercept_2022 = model_intercept.predict(np.array([15]).reshape(-1,1))

model_coef = ln.fit(year_since_1980,coef_autumn)
coef_2022 = model_coef.predict(np.array([15]).reshape(-1,1))

x_2022_autumn = [select["j-th-day"].iloc[-1]+60+1,select["j-th-day"].iloc[-1]+60+1+90]

y_2022_autumn = [coef_2022*x_2022[0]+intercept_2022,coef_2022*x_2022[1]+intercept_2022]

ax2.plot(x_2022_autumn,y_2022_autumn,color='red',label='Autumn')


#Calculte the model for Summer(Feb,Jan) 2022

intercept_summer = intercept_summer[24:]
coef_summer = coef_summer[24:]

year_since_1980_summer = np.array(list(range(len(intercept_summer)))).reshape(-1,1)
model_intercept_summer = ln.fit(year_since_1980_summer,intercept_summer)
intercept_2022_summer = model_intercept_summer.predict(np.array([18]).reshape(-1,1))

model_coef_summer = ln.fit(year_since_1980_summer,coef_summer)
coef_2022_summer = model_coef_summer.predict(np.array([18]).reshape(-1,1))

x_2022_summer = [select["j-th-day"].iloc[-1]+1,select["j-th-day"].iloc[-1]+59+1]
y_2022_summer = [coef_2022_summer*x_2022_summer[0]+intercept_2022_summer,coef_2022_summer*x_2022_summer[1]+intercept_2022_summer]


ax2.plot(x_2022_summer,y_2022_summer,color='brown',label='Summer')

#Calculte the model for Spring 2022

intercept_spring = intercept_spring[24:]
coef_spring = coef_spring[24:]

year_since_1980_spring = np.array(list(range(len(intercept_spring)))).reshape(-1,1)
model_intercept_spring = ln.fit(year_since_1980_spring,intercept_spring)
intercept_2022_spring = model_intercept_spring.predict(np.array([18]).reshape(-1,1))

model_coef_spring = ln.fit(year_since_1980_spring,coef_spring)
coef_2022_spring = model_coef_spring.predict(np.array([18]).reshape(-1,1))

x_2022_spring = [select["j-th-day"].iloc[-1]+1+242,select["j-th-day"].iloc[-1]+333+1]
y_2022_spring = [coef_2022_spring*x_2022_spring[0]+intercept_2022_spring,coef_2022_spring*x_2022_spring[1]+intercept_2022_spring]

ax2.plot(x_2022_spring,y_2022_spring,label='Spring')

##Calculte the model for Summer(Dec) 2022

intercept_2022_summer_Dec = model_intercept_summer.predict(np.array([19]).reshape(-1,1))
coef_2022_summer_Dec = model_coef_summer.predict(np.array([19]).reshape(-1,1))
x_2022_summer_Dec = [select["j-th-day"].iloc[-1]+334+1,select["j-th-day"].iloc[-1]+365+1]
y_2022_summer_Dec = [coef_2022_summer*x_2022_summer[0]+intercept_2022_summer,coef_2022_summer*x_2022_summer[1]+intercept_2022_summer]
ax2.plot(x_2022_summer_Dec,y_2022_summer_Dec,color='gold',label='Summer_Dec')



##Calculte the model for Winter 2022

intercept_winter = intercept_winter[24:]
coef_winter = coef_winter[24:]

year_since_1980_winter = np.array(list(range(len(intercept_winter)))).reshape(-1,1)
model_intercept_winter = ln.fit(year_since_1980_winter,intercept_winter)
intercept_2022_winter= model_intercept_winter.predict(np.array([18]).reshape(-1,1))

model_coef_winter = ln.fit(year_since_1980_winter,coef_winter)
coef_2022_winter = model_coef_winter.predict(np.array([18]).reshape(-1,1))

x_2022_winter = [select["j-th-day"].iloc[-1]+1+151,select["j-th-day"].iloc[-1]+242+1]
y_2022_winter = [coef_2022_winter*x_2022_winter[0]+intercept_2022_winter,coef_2022_winter*x_2022_winter[1]+intercept_2022_winter]

ax2.plot(x_2022_winter,y_2022_winter,color='blue',label='Winter')

#Plot the second graph,actual Anatarctic sea ice extent versus the days in 2022
x_2022 = range(select["j-th-day"].iloc[-1]+1,select["j-th-day"].iloc[-1]+1+365)
actual_2022 = SeaIce.loc[(SeaIce["Date"]>="2022-01-01")&(SeaIce["Date"]<="2022-12-31")]["Sum_Antarctic"]
ax2.scatter(x_2022,actual_2022,color="green",label='actual')

ax2.set_title('Actual Sea Ice extent and predicted Sea ice extent in 2022')
ax2.set_xlabel('Days since 1980-01-01')
ax2.set_ylabel('Antarctic Sea Ice extent')
ax2.legend()
# Out:
# /var/folders/w3/1bhj1k9n00jbh6lvpf14z78r0000gn/T/ipykernel_2044/3814667198.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   select["season"] = select["Month"].apply(to_season)

# %% [raw]
# # YOUR WRITTEN ANSWER HERE

# %% [markdown]
# - Task 3: Perform the same study as above (taking both Tasks 1 and 2 into consideration) but build 12 linear regression models for each year where one for each month in the year (8 marks: the marks in each of the five parts in Task 1 above are halved.)

# %%
# YOUR CODE HERE

#Set the figure size for two graph
fig = plt.figure(figsize=(25,30))
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

#Collect intercept and coef for each season in 1980 to 2021,use these datas later to create a model to predict intercept and coef in 2022
intercept_Jan = []
coef_Jan = []

intercept_Feb = []
coef_Feb = []

intercept_Mar = []
coef_Mar = []

intercept_Apr = []
coef_Apr = []

intercept_May = []
coef_May = []

intercept_June = []
coef_June = []

intercept_July = []
coef_July = []

intercept_Aug = []
coef_Aug = []

intercept_Sep = []
coef_Sep = []

intercept_Oct = []
coef_Oct = []

intercept_Nov = []
coef_Nov = []

intercept_Dec = []
coef_Dec = []

#Create model and plot for each month
for i in range(1980,2022):
    data = select[(select['Month']==1) & (select['Year']==i)]
    x = np.array(data["j-th-day"]).reshape(-1,1)
    y = data["Sum_Antarctic"]
    lr = LinearRegression()
    model = lr.fit(x,y)
    intercept = model.intercept_
    coef = model.coef_[0]
    y_min = x.min()*coef+intercept
    y_max = x.max()*coef+intercept
    x1 = [x.min(),x.max()]
    y1 = [y_min,y_max]
    intercept_Jan.append(intercept)
    coef_Jan.append(coef)
    ax1.plot(x1,y1,color='red')
    
    data = select[(select['Month']==2) & (select['Year']==i)]
    x = np.array(data["j-th-day"]).reshape(-1,1)
    y = data["Sum_Antarctic"]
    lr = LinearRegression()
    model = lr.fit(x,y)
    intercept = model.intercept_
    coef = model.coef_[0]
    y_min = x.min()*coef+intercept
    y_max = x.max()*coef+intercept
    x1 = [x.min(),x.max()]
    y1 = [y_min,y_max]
    intercept_Feb.append(intercept)
    coef_Feb.append(coef)
    ax1.plot(x1,y1,color='green')
    
    data = select[(select['Month']==3) & (select['Year']==i)]
    x = np.array(data["j-th-day"]).reshape(-1,1)
    y = data["Sum_Antarctic"]
    lr = LinearRegression()
    model = lr.fit(x,y)
    intercept = model.intercept_
    coef = model.coef_[0]
    y_min = x.min()*coef+intercept
    y_max = x.max()*coef+intercept
    x1 = [x.min(),x.max()]
    y1 = [y_min,y_max]
    intercept_Mar.append(intercept)
    coef_Mar.append(coef)
    ax1.plot(x1,y1,color='blue')
    
    data = select[(select['Month']==4) & (select['Year']==i)]
    x = np.array(data["j-th-day"]).reshape(-1,1)
    y = data["Sum_Antarctic"]
    lr = LinearRegression()
    model = lr.fit(x,y)
    intercept = model.intercept_
    coef = model.coef_[0]
    y_min = x.min()*coef+intercept
    y_max = x.max()*coef+intercept
    x1 = [x.min(),x.max()]
    y1 = [y_min,y_max]
    intercept_Apr.append(intercept)
    coef_Apr.append(coef)
    ax1.plot(x1,y1,color='brown')
    
    data = select[(select['Month']==5) & (select['Year']==i)]
    x = np.array(data["j-th-day"]).reshape(-1,1)
    y = data["Sum_Antarctic"]
    lr = LinearRegression()
    model = lr.fit(x,y)
    intercept = model.intercept_
    coef = model.coef_[0]
    y_min = x.min()*coef+intercept
    y_max = x.max()*coef+intercept
    x1 = [x.min(),x.max()]
    y1 = [y_min,y_max]
    intercept_May.append(intercept)
    coef_May.append(coef)
    ax1.plot(x1,y1,color='yellow')
    
    data = select[(select['Month']==6) & (select['Year']==i)]
    x = np.array(data["j-th-day"]).reshape(-1,1)
    y = data["Sum_Antarctic"]
    lr = LinearRegression()
    model = lr.fit(x,y)
    intercept = model.intercept_
    coef = model.coef_[0]
    y_min = x.min()*coef+intercept
    y_max = x.max()*coef+intercept
    x1 = [x.min(),x.max()]
    y1 = [y_min,y_max]
    intercept_June.append(intercept)
    coef_June.append(coef)
    ax1.plot(x1,y1,color='grey')
    
    data = select[(select['Month']==7) & (select['Year']==i)]
    x = np.array(data["j-th-day"]).reshape(-1,1)
    y = data["Sum_Antarctic"]
    lr = LinearRegression()
    model = lr.fit(x,y)
    intercept = model.intercept_
    coef = model.coef_[0]
    y_min = x.min()*coef+intercept
    y_max = x.max()*coef+intercept
    x1 = [x.min(),x.max()]
    y1 = [y_min,y_max]
    intercept_July.append(intercept)
    coef_July.append(coef)
    ax1.plot(x1,y1,color='gold')
    
    data = select[(select['Month']==8) & (select['Year']==i)]
    x = np.array(data["j-th-day"]).reshape(-1,1)
    y = data["Sum_Antarctic"]
    lr = LinearRegression()
    model = lr.fit(x,y)
    intercept = model.intercept_
    coef = model.coef_[0]
    y_min = x.min()*coef+intercept
    y_max = x.max()*coef+intercept
    x1 = [x.min(),x.max()]
    y1 = [y_min,y_max]
    intercept_Aug.append(intercept)
    coef_Aug.append(coef)
    ax1.plot(x1,y1,color='silver')
    
    data = select[(select['Month']==9) & (select['Year']==i)]
    x = np.array(data["j-th-day"]).reshape(-1,1)
    y = data["Sum_Antarctic"]
    lr = LinearRegression()
    model = lr.fit(x,y)
    intercept = model.intercept_
    coef = model.coef_[0]
    y_min = x.min()*coef+intercept
    y_max = x.max()*coef+intercept
    x1 = [x.min(),x.max()]
    y1 = [y_min,y_max]
    intercept_Sep.append(intercept)
    coef_Sep.append(coef)
    ax1.plot(x1,y1,color='tan')
    
    data = select[(select['Month']==10) & (select['Year']==i)]
    x = np.array(data["j-th-day"]).reshape(-1,1)
    y = data["Sum_Antarctic"]
    lr = LinearRegression()
    model = lr.fit(x,y)
    intercept = model.intercept_
    coef = model.coef_[0]
    y_min = x.min()*coef+intercept
    y_max = x.max()*coef+intercept
    x1 = [x.min(),x.max()]
    y1 = [y_min,y_max]
    intercept_Oct.append(intercept)
    coef_Oct.append(coef)
    ax1.plot(x1,y1,color='pink')
    
    data = select[(select['Month']==11) & (select['Year']==i)]
    x = np.array(data["j-th-day"]).reshape(-1,1)
    y = data["Sum_Antarctic"]
    lr = LinearRegression()
    model = lr.fit(x,y)
    intercept = model.intercept_
    coef = model.coef_[0]
    y_min = x.min()*coef+intercept
    y_max = x.max()*coef+intercept
    x1 = [x.min(),x.max()]
    y1 = [y_min,y_max]
    intercept_Nov.append(intercept)
    coef_Nov.append(coef)
    ax1.plot(x1,y1,color='violet')
    
    data = select[(select['Month']==12) & (select['Year']==i)]
    x = np.array(data["j-th-day"]).reshape(-1,1)
    y = data["Sum_Antarctic"]
    lr = LinearRegression()
    model = lr.fit(x,y)
    intercept = model.intercept_
    coef = model.coef_[0]
    y_min = x.min()*coef+intercept
    y_max = x.max()*coef+intercept
    x1 = [x.min(),x.max()]
    y1 = [y_min,y_max]
    intercept_Dec.append(intercept)
    coef_Dec.append(coef)
    ax1.plot(x1,y1,color='olive')

#Set the element for first graph
ax1.set_title('Linear regression model line for each month between 1980 and 2021')
ax1.set_xlabel('Days since 1980-01-01')
ax1.set_ylabel('Antarctic Sea Ice extent')
ax1.legend(['Jan','Feb','March','Apr','May','June','July','Aug','Sep','Oct','Nov','Dec'])

#Draw the actual sea ice extent on the second graph by scatter plot
x_2022 = range(select["j-th-day"].iloc[-1]+1,select["j-th-day"].iloc[-1]+1+365)
actual_2022 = SeaIce.loc[(SeaIce["Date"]>="2022-01-01")&(SeaIce["Date"]<="2022-12-31")]["Sum_Antarctic"]
ax2.scatter(x_2022,actual_2022,color="black",label='actual')

# Draw the model for Janauray
ln = LinearRegression()

intercept_Jan = intercept_Jan[25:]
coef_Jan = coef_Jan[25:]
year_since_1980 = np.array(list(range(len(intercept_Jan)))).reshape(-1,1)
model_intercept = ln.fit(year_since_1980,intercept_Jan)
intercept_2022 = model_intercept.predict(np.array([17]).reshape(-1,1))
model_coef = ln.fit(year_since_1980,coef_Jan)
coef_2022 = model_coef.predict(np.array([17]).reshape(-1,1))
x_2022 = [select["j-th-day"].iloc[-1]+1,select["j-th-day"].iloc[-1]+1+31]
y_2022 = [coef_2022*x_2022[0]+intercept_2022,coef_2022*x_2022[1]+intercept_2022]
ax2.plot(x_2022,y_2022,color='red',label='Jan')

# Draw the model for Feb
intercept_Feb = intercept_Feb[28:]
coef_Feb = coef_Feb[28:]
year_since_1980 = np.array(list(range(len(intercept_Feb)))).reshape(-1,1)
model_intercept = ln.fit(year_since_1980,intercept_Feb)
intercept_2022 = model_intercept.predict(np.array([14]).reshape(-1,1))
model_coef = ln.fit(year_since_1980,coef_Feb)
coef_2022 = model_coef.predict(np.array([14]).reshape(-1,1))
x_2022 = [select["j-th-day"].iloc[-1]+1+32,select["j-th-day"].iloc[-1]+1+31+28]
y_2022 = [coef_2022*x_2022[0]+intercept_2022,coef_2022*x_2022[1]+intercept_2022]
ax2.plot(x_2022,y_2022,color='green',label='Feb')

# Draw the model for Mar
intercept_Mar = intercept_Mar[28:]
coef_Mar = coef_Mar[28:]
year_since_1980 = np.array(list(range(len(intercept_Mar)))).reshape(-1,1)
model_intercept = ln.fit(year_since_1980,intercept_Mar)
intercept_2022 = model_intercept.predict(np.array([14]).reshape(-1,1))
model_coef = ln.fit(year_since_1980,coef_Mar)
coef_2022 = model_coef.predict(np.array([14]).reshape(-1,1))
x_2022 = [select["j-th-day"].iloc[-1]+1+31+28,select["j-th-day"].iloc[-1]+1+31+28+31]
y_2022 = [coef_2022*x_2022[0]+intercept_2022,coef_2022*x_2022[1]+intercept_2022]
ax2.plot(x_2022,y_2022,color='blue',label='March')

# Draw the model for Apr
intercept_Apr = intercept_Apr[25:]
coef_Apr = coef_Apr[25:]
year_since_1980 = np.array(list(range(len(intercept_Apr)))).reshape(-1,1)
model_intercept = ln.fit(year_since_1980,intercept_Apr)
intercept_2022 = model_intercept.predict(np.array([17]).reshape(-1,1))
model_coef = ln.fit(year_since_1980,coef_Apr)
coef_2022 = model_coef.predict(np.array([17]).reshape(-1,1))
x_2022 = [select["j-th-day"].iloc[-1]+1+90,select["j-th-day"].iloc[-1]+1+90+29]
y_2022 = [coef_2022*x_2022[0]+intercept_2022,coef_2022*x_2022[1]+intercept_2022]
ax2.plot(x_2022,y_2022,color='brown',label='April')

# Draw the model for May
intercept_May = intercept_May[28:]
coef_May = coef_May[28:]
year_since_1980 = np.array(list(range(len(intercept_May)))).reshape(-1,1)
model_intercept = ln.fit(year_since_1980,intercept_May)
intercept_2022 = model_intercept.predict(np.array([14]).reshape(-1,1))
model_coef = ln.fit(year_since_1980,coef_May)
coef_2022 = model_coef.predict(np.array([14]).reshape(-1,1))
x_2022 = [select["j-th-day"].iloc[-1]+1+90+30,select["j-th-day"].iloc[-1]+1+90+29+30]
y_2022 = [coef_2022*x_2022[0]+intercept_2022,coef_2022*x_2022[1]+intercept_2022]
ax2.plot(x_2022,y_2022,color='yellow',label='May')

# Draw the model for June
intercept_June = intercept_June[35:]
coef_June = coef_June[35:]
year_since_1980 = np.array(list(range(len(intercept_June)))).reshape(-1,1)
model_intercept = ln.fit(year_since_1980,intercept_June)
intercept_2022 = model_intercept.predict(np.array([7]).reshape(-1,1))
model_coef = ln.fit(year_since_1980,coef_June)
coef_2022 = model_coef.predict(np.array([7]).reshape(-1,1))
x_2022 = [select["j-th-day"].iloc[-1]+1+90+30+31,select["j-th-day"].iloc[-1]+1+90+29+30+31]
y_2022 = [coef_2022*x_2022[0]+intercept_2022,coef_2022*x_2022[1]+intercept_2022]
ax2.plot(x_2022,y_2022,color='grey',label='June')

# Draw the model for July
intercept_July = intercept_July[27:]
coef_July = coef_July[27:]
year_since_1980 = np.array(list(range(len(intercept_July)))).reshape(-1,1)
model_intercept = ln.fit(year_since_1980,intercept_July)
intercept_2022 = model_intercept.predict(np.array([15]).reshape(-1,1))
model_coef = ln.fit(year_since_1980,coef_July)
coef_2022 = model_coef.predict(np.array([15]).reshape(-1,1))
x_2022 = [select["j-th-day"].iloc[-1]+1+90+30+31+30,select["j-th-day"].iloc[-1]+1+90+29+30+31+30]
y_2022 = [coef_2022*x_2022[0]+intercept_2022,coef_2022*x_2022[1]+intercept_2022]
ax2.plot(x_2022,y_2022,color='gold',label='July')

# Draw the model for Aug
intercept_Aug = intercept_Aug[15:]
coef_Aug = coef_Aug[15:]
year_since_1980 = np.array(list(range(len(intercept_Aug)))).reshape(-1,1)
model_intercept = ln.fit(year_since_1980,intercept_Aug)
intercept_2022 = model_intercept.predict(np.array([27]).reshape(-1,1))
model_coef = ln.fit(year_since_1980,coef_Aug)
coef_2022 = model_coef.predict(np.array([27]).reshape(-1,1))
x_2022 = [select["j-th-day"].iloc[-1]+1+90+30+31+30+31,select["j-th-day"].iloc[-1]+1+90+29+30+31+30+31]
y_2022 = [coef_2022*x_2022[0]+intercept_2022,coef_2022*x_2022[1]+intercept_2022]
ax2.plot(x_2022,y_2022,color='silver',label='August')

# Draw the model for Sep
intercept_Sep = intercept_Sep[27:]
coef_Sep = coef_Sep[27:]
year_since_1980 = np.array(list(range(len(intercept_Sep)))).reshape(-1,1)
model_intercept = ln.fit(year_since_1980,intercept_Sep)
intercept_2022 = model_intercept.predict(np.array([15]).reshape(-1,1))
model_coef = ln.fit(year_since_1980,coef_Sep)
coef_2022 = model_coef.predict(np.array([15]).reshape(-1,1))
x_2022 = [select["j-th-day"].iloc[-1]+1+90+30+31+30+31+31,select["j-th-day"].iloc[-1]+1+90+29+30+31+30+31+31]
y_2022 = [coef_2022*x_2022[0]+intercept_2022,coef_2022*x_2022[1]+intercept_2022]
ax2.plot(x_2022,y_2022,color='tan',label='Sep')

# Draw the model for Oct
intercept_Oct = intercept_Oct[35:]
coef_Oct = coef_Oct[35:]
year_since_1980 = np.array(list(range(len(intercept_Oct)))).reshape(-1,1)
model_intercept = ln.fit(year_since_1980,intercept_Oct)
intercept_2022 = model_intercept.predict(np.array([7]).reshape(-1,1))
model_coef = ln.fit(year_since_1980,coef_Oct)
coef_2022 = model_coef.predict(np.array([7]).reshape(-1,1))
x_2022 = [select["j-th-day"].iloc[-1]+1+90+30+31+30+31+31+30,select["j-th-day"].iloc[-1]+1+90+29+30+31+30+31+31+30]
y_2022 = [coef_2022*x_2022[0]+intercept_2022,coef_2022*x_2022[1]+intercept_2022]
ax2.plot(x_2022,y_2022,color='pink',label='Oct')

# Draw the model for Nov
intercept_Nov = intercept_Nov[35:]
coef_Nov = coef_Nov[35:]
year_since_1980 = np.array(list(range(len(intercept_Nov)))).reshape(-1,1)
model_intercept = ln.fit(year_since_1980,intercept_Nov)
intercept_2022 = model_intercept.predict(np.array([7]).reshape(-1,1))
model_coef = ln.fit(year_since_1980,coef_Nov)
coef_2022 = model_coef.predict(np.array([7]).reshape(-1,1))
x_2022 = [select["j-th-day"].iloc[-1]+1+90+30+31+30+31+31+30+31,select["j-th-day"].iloc[-1]+1+90+29+30+31+30+31+31+30+31]
y_2022 = [coef_2022*x_2022[0]+intercept_2022,coef_2022*x_2022[1]+intercept_2022]
ax2.plot(x_2022,y_2022,color='violet',label='Nov')

# Draw the model for Dec
intercept_Dec = intercept_Dec[40:]
coef_Dec = coef_Dec[40:]
year_since_1980 = np.array(list(range(len(intercept_Dec)))).reshape(-1,1)
model_intercept = ln.fit(year_since_1980,intercept_Dec)
intercept_2022 = model_intercept.predict(np.array([2]).reshape(-1,1))
model_coef = ln.fit(year_since_1980,coef_Dec)
coef_2022 = model_coef.predict(np.array([2]).reshape(-1,1))
x_2022 = [select["j-th-day"].iloc[-1]+1+90+30+31+30+31+31+30+31+30,select["j-th-day"].iloc[-1]+1+90+29+30+31+30+31+31+30+31+30]
y_2022 = [coef_2022*x_2022[0]+intercept_2022,coef_2022*x_2022[1]+intercept_2022]
ax2.plot(x_2022,y_2022,color='olive',label='Dec')

#Set the element of second picture
ax2.set_title('Actual Sea Ice extent and predicted Sea ice extent in 2022')
ax2.set_xlabel('Days since 1980-01-01')
ax2.set_ylabel('Antarctic Sea Ice extent')
ax2.legend()

# %% [raw]
# # YOUR WRITTEN ANSWER HERE

# %% [markdown]
# - Task 4: Compare and discuss the performance of models developed in Task 1, 2, and 3. (4 marks)

# %%
# YOUR CODE HERE

# %% [raw]
# # YOUR WRITTEN ANSWER HERE
# The perfomacne of models in task1,task2 and task3 are different. In the first task,we get out model base on the all sea ice extent from 1980-2021,in the second model, we use each seasons from 1980 to 2021.For the last model,we use the each month from 1980 to 2021.Compare to the actual data in 2022, the first model has the least accuracy,while the second model is much more accuarcy and the last one are most accuarated compare to other two.The reason for this is if we use separate the data(Sea Ice extent) into a smaller parts,so we could predict the outcome of the data much more accuary. For each small model,it closer to actual data compare to large scale linear regression model.

# %% [markdown]
# - Task 5 (for bonus marks): Be creative and develop your own models using the data until 2021 and apply it to predict the sea ice extent of the year of 2022. The goal is to develop a model which gives smaller root mean squared errors than those from the models developed above. You can use Arctic data here if it helps (only for this Task in Q3). (5 bonus marks)

# %%
# YOUR CODE HERE

fig = plt.figure(figsize=(25,30))
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

start_1 = "2005-01-01"
end_1 = "2021-12-31"
select_2005 = select.loc[(select["Date"]>=start_1)&(select["Date"]<=end_1)]
select_2005['j-th-day'] = select_2005['j-th-day']-9132

week = int(len(select_2005)/7)
week_column = []
for i in range(1,week+1):
    week_column.append(i)
    week_column.append(i)
    week_column.append(i)
    week_column.append(i)
    week_column.append(i)
    week_column.append(i)
    week_column.append(i)

select_2005['week'] = week_column      

coef_week = []
intercept_week = []
for i in range(1,week+1):
    data = select_2005[(select_2005['week']==i)]
    x = np.array(data["j-th-day"]).reshape(-1,1)
    y = data["Sum_Antarctic"]
    lr = LinearRegression()
    model = lr.fit(x,y)
    intercept = model.intercept_
    coef = model.coef_[0]
    y_min = x.min()*coef+intercept
    y_max = x.max()*coef+intercept
    x1 = [x.min(),x.max()]
    y1 = [y_min,y_max]
    coef_week.append(coef)
    intercept_week.append(intercept)
    ax1.plot(x1,y1,color='red')

ax1.set_title('Linear regression model line for each week between 2005 and 2021')
ax1.set_xlabel('Days since 2005-01-01')
ax1.set_ylabel('Antarctic Sea Ice extent')
ax1.legend(['sea ice extent'])





for i in range(0,1):
    coef_temp = coef_week[i::52]
    intercept_temp = intercept_week[i::52]
    week_since_2005 = np.array(list(range(len(intercept_temp)))).reshape(-1,1)
    model_intercept = ln.fit(week_since_2005,intercept_temp)
    intercept_2022 = model_intercept.predict(np.array([17]).reshape(-1,1))
    model_coef = ln.fit(week_since_2005,coef_temp)
    coef_2022 = model_coef.predict(np.array([17]).reshape(-1,1))
    x_2022 = [select_2005["j-th-day"].iloc[-1]+1,select["j-th-day"].iloc[-1]+7]
    y_2022 = [coef_2022*x_2022[0]+intercept_2022,coef_2022*x_2022[1]+intercept_2022]
    ax2.plot(x_2022,y_2022,color='violet')
    
    

#Draw the actual sea ice extent on the second graph by scatter plot
x_2022 = range(select_2005["j-th-day"].iloc[-1]+1,select_2005["j-th-day"].iloc[-1]+1+365)
actual_2022 = SeaIce.loc[(SeaIce["Date"]>="2022-01-01")&(SeaIce["Date"]<="2022-12-31")]["Sum_Antarctic"]
ax2.scatter(x_2022,actual_2022,color="black",label='actual')

#Set the element of second picture
ax2.set_title('Actual Sea Ice extent and predicted Sea ice extent in 2022')
ax2.set_xlabel('Days since 1980-01-01')
ax2.set_ylabel('Antarctic Sea Ice extent')
ax2.legend()
# Out:
# /var/folders/w3/1bhj1k9n00jbh6lvpf14z78r0000gn/T/ipykernel_2044/1136524754.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   select_2005['j-th-day'] = select_2005['j-th-day']-9132
# /var/folders/w3/1bhj1k9n00jbh6lvpf14z78r0000gn/T/ipykernel_2044/1136524754.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   select_2005['week'] = week_column

# %% [raw]
# # YOUR WRITTEN ANSWER HERE
# # Create a model for each 7 days betweeen 2005 and 2021,make the data for each model smaller and more fit to actual data.
